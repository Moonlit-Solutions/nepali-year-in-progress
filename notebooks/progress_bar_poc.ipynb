# %%
from googletrans import Translator

# %%
translator = Translator()
translator.translate('33', dest='ne').text
# Out:
# '33'

# %%
comp = ['█','░']

# %%
comp[0]
# Out:
# '█'

# %%
comp[1]
# Out:
# '░'

# %%
day_of_year = 100
number_of_days = 365
shrink_factor = 4
shrink = 100/shrink_factor

# %%
comp[0]*int((day_of_year/number_of_days)*25)+comp[1]*int((1-(day_of_year/number_of_days))*25)+' '+str(int((day_of_year/number_of_days)*100))+'%'
# Out:
# '██████░░░░░░░░░░░░░░░░░░ 27%'

# %%
final_dict = {}
for i in range (1, 366):
    day_of_year = i
    number_of_days = 365
    shrink_factor = 4
    shrink = 100/shrink_factor
    final_dict[str(round((day_of_year/number_of_days)*100))] = [day_of_year, (comp[0]*round((day_of_year/number_of_days)*shrink)+comp[1]*round((1-(day_of_year/number_of_days))*shrink)+' '+str(round((day_of_year/number_of_days)*100))+'%')]
final_dict
# Out:
# {'0': [1, '░░░░░░░░░░░░░░░░░░░░░░░░░ 0%'],
#  '1': [5, '░░░░░░░░░░░░░░░░░░░░░░░░░ 1%'],
#  '2': [9, '█░░░░░░░░░░░░░░░░░░░░░░░░ 2%'],
#  '3': [12, '█░░░░░░░░░░░░░░░░░░░░░░░░ 3%'],
#  '4': [16, '█░░░░░░░░░░░░░░░░░░░░░░░░ 4%'],
#  '5': [20, '█░░░░░░░░░░░░░░░░░░░░░░░░ 5%'],
#  '6': [23, '██░░░░░░░░░░░░░░░░░░░░░░░ 6%'],
#  '7': [27, '██░░░░░░░░░░░░░░░░░░░░░░░ 7%'],
#  '8': [31, '██░░░░░░░░░░░░░░░░░░░░░░░ 8%'],
#  '9': [34, '██░░░░░░░░░░░░░░░░░░░░░░░ 9%'],
#  '10': [38, '███░░░░░░░░░░░░░░░░░░░░░░ 10%'],
#  '11': [41, '███░░░░░░░░░░░░░░░░░░░░░░ 11%'],
#  '12': [45, '███░░░░░░░░░░░░░░░░░░░░░░ 12%'],
#  '13': [49, '███░░░░░░░░░░░░░░░░░░░░░░ 13%'],
#  '14': [52, '████░░░░░░░░░░░░░░░░░░░░░ 14%'],
#  '15': [56, '████░░░░░░░░░░░░░░░░░░░░░ 15%'],
#  '16': [60, '████░░░░░░░░░░░░░░░░░░░░░ 16%'],
#  '17': [63, '████░░░░░░░░░░░░░░░░░░░░░ 17%'],
#  '18': [67, '█████░░░░░░░░░░░░░░░░░░░░ 18%'],
#  '19': [71, '█████░░░░░░░░░░░░░░░░░░░░ 19%'],
#  '20': [74, '█████░░░░░░░░░░░░░░░░░░░░ 20%'],
# ...

# %%
final_dict2 = {}
for key in final_dict:
    final_dict2[final_dict[key][0]] = final_dict[key][1]

# %%
final_dict2
# Out:
# {1: '░░░░░░░░░░░░░░░░░░░░░░░░░ 0%',
#  5: '░░░░░░░░░░░░░░░░░░░░░░░░░ 1%',
#  9: '█░░░░░░░░░░░░░░░░░░░░░░░░ 2%',
#  12: '█░░░░░░░░░░░░░░░░░░░░░░░░ 3%',
#  16: '█░░░░░░░░░░░░░░░░░░░░░░░░ 4%',
#  20: '█░░░░░░░░░░░░░░░░░░░░░░░░ 5%',
#  23: '██░░░░░░░░░░░░░░░░░░░░░░░ 6%',
#  27: '██░░░░░░░░░░░░░░░░░░░░░░░ 7%',
#  31: '██░░░░░░░░░░░░░░░░░░░░░░░ 8%',
#  34: '██░░░░░░░░░░░░░░░░░░░░░░░ 9%',
#  38: '███░░░░░░░░░░░░░░░░░░░░░░ 10%',
#  41: '███░░░░░░░░░░░░░░░░░░░░░░ 11%',
#  45: '███░░░░░░░░░░░░░░░░░░░░░░ 12%',
#  49: '███░░░░░░░░░░░░░░░░░░░░░░ 13%',
#  52: '████░░░░░░░░░░░░░░░░░░░░░ 14%',
#  56: '████░░░░░░░░░░░░░░░░░░░░░ 15%',
#  60: '████░░░░░░░░░░░░░░░░░░░░░ 16%',
#  63: '████░░░░░░░░░░░░░░░░░░░░░ 17%',
#  67: '█████░░░░░░░░░░░░░░░░░░░░ 18%',
#  71: '█████░░░░░░░░░░░░░░░░░░░░ 19%',
#  74: '█████░░░░░░░░░░░░░░░░░░░░ 20%',
#  78: '█████░░░░░░░░░░░░░░░░░░░░ 21%',
#  82: '██████░░░░░░░░░░░░░░░░░░░ 22%',
#  85: '██████░░░░░░░░░░░░░░░░░░░ 23%',
#  89: '██████░░░░░░░░░░░░░░░░░░░ 24%',
# ...
